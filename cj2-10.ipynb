# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.binomial(10,0.25,1000)


plt.hist(x,bins = 100,alpha= 0.5,edgecolor = "black" )

plt.ylabel('Frequency')
plt.xlabel('Successes')

plt.savefig('histogram.pdf')
